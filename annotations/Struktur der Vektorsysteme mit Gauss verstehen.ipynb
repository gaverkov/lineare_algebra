# %%
#data = [(3,3),(4,7),(1,3),(2,1),(0,0)]
#data = [(0,0),(1, 0), (1, 2), (2, 2), (2, 0), (4, 0), (4, 4), (2, 6), (0, 4), (0, 0)]
data = [(0, 0), (1, 1), (3, 5), (4, 6), (2, 2), (4, 4), (8, 12), (8, 14), (4, 8), (0, 0)]
A = matrix(QQ,data).transpose()
print(A)
PLOT_A = line(A.columns(),color='blue',thickness=3) + point(A.columns(),size=60,color='black')
show(PLOT_A)
B = A.with_added_multiple_of_row(1,0,-2)
print(B)
PLOT_B = line(B.columns(),color='red',thickness=3)
show(PLOT_B)
C = B.with_added_multiple_of_row(1,0,1)
print(C)
PLOT_C = line(C.columns(),thickness=3,color='orange')
show(PLOT_C)
# Out:
# [ 0  1  3  4  2  4  8  8  4  0]
# [ 0  1  5  6  2  4 12 14  8  0]
# Graphics object consisting of 2 graphics primitives
# [ 0  1  3  4  2  4  8  8  4  0]
# [ 0 -1 -1 -2 -2 -4 -4 -2  0  0]
# Graphics object consisting of 1 graphics primitive
# [0 1 3 4 2 4 8 8 4 0]
# [0 0 2 2 0 0 4 6 4 0]
# Graphics object consisting of 1 graphics primitive

# %%
M = matrix([(0,0),(1,0),(1,1),(2,1),(2,0),(3,0),(3,2),(0,2),(0,0)]).transpose()
print(M)
PLOT1 = line(M.columns(),color='blue',thickness=3)
show(PLOT1)
N = M.with_added_multiple_of_row(1,0,1)
print(N)
PLOT2 = line(N.columns(),color='red',thickness=3)
show(PLOT2)
# Out:
# [0 1 1 2 2 3 3 0 0]
# [0 0 1 1 0 0 2 2 0]
# Graphics object consisting of 1 graphics primitive
# [0 1 1 2 2 3 3 0 0]
# [0 1 2 3 2 3 5 2 0]
# Graphics object consisting of 1 graphics primitive

# %%
B = matrix(RDF,[(0,0),(1,0),(2,0),(0,1),(1,1),(2,1),(0,2),(1,2),(2,2)]).transpose()
print(B)
phi = 3.14/6 + 3.14

A = matrix(RDF,[(cos(phi),sin(phi)),(-sin(phi),cos(phi))]).transpose()
print(A)
# Out:
# [0.0 1.0 2.0 0.0 1.0 2.0 0.0 1.0 2.0]
# [0.0 0.0 0.0 1.0 1.0 1.0 2.0 2.0 2.0]
# [-0.8669529561925529  0.4983899795832512]
# [-0.4983899795832512 -0.8669529561925529]

# %%
show(point(B.columns(),size=50) + point((A*B).columns() ,size=50,color='red') ,aspect_ratio=1)
# Out:
# Graphics object consisting of 2 graphics primitives
